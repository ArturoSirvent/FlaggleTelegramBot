# %%
#librerias 
from bs4 import BeautifulSoup
import requests
import numpy as np 
import matplotlib.pyplot as plt 
import unidecode
import re 
import telebot

# %%
HANGMANPICS = ['''
  +------+
  |      |
         |
         |
         |
         |
=========''', '''
  +------+
  |      |
 O     |
         |
         |
         |
=========''', '''
  +------+
  |      |
 O     |
  |      |
         |
         |
=========''', '''
  +------+
  |      |
 O     |
 /|     |
         |
         |
=========''', '''
  +------+
  |      |
 O     |
 /|\    |
         |
         |
=========''', '''
  +------+
  |      |
 O     |
 /|\    |
 /       |
         |
=========''', '''
  +------+
  |      |
 O     |
 /|\    |
 / \     |
         |
=========''']

# %%
#el diccionario de palabras lo vamos a sacar de 
#https://es.wiktionary.org/wiki/Ap%C3%A9ndice:1000_palabras_b%C3%A1sicas_en_espa%C3%B1ol  
#con webscraping
url="https://es.wiktionary.org/wiki/Ap%C3%A9ndice:1000_palabras_b%C3%A1sicas_en_espa%C3%B1ol  "
r=requests.get(url)
soup=BeautifulSoup(r.content,parser="html.parser")

# %%
lis=soup.find_all("li",class_="")
palabras=[]
for i in lis:
    try:
        if (len(i.a.text)>=6 and len(i.a.text.split())==1):
            palabras.append(i.a.text)
        else:
            pass
    except:
        pass
#quito las ultimas 4 porque parecen un eror o algo
palabras=palabras[:-4]
palabras=[unidecode.unidecode(i).lower() for i in palabras]
palabras
# Out:
# ['humanidad',
#  'humano',
#  'persona',
#  'hombre',
#  'adolescente',
#  'adulto',
#  'anciano',
#  'caballero',
#  'individuo',
#  'cuerpo',
#  'pierna',
#  'espinilla',
#  'rodilla',
#  'cabeza',
#  'diente',
#  'bigote',
#  'cabello',
#  'cerebro',
#  'estomago',
#  'hombro',
#  'muneca',
#  'trasero',
#  'abdomen',
#  'higado',
#  'musculo',
#  'cuello',
#  'corazon',
#  'espiritu',
#  'cintura',
#  'cadera',
#  'espalda',
#  'sangre',
#  'resfriado',
#  'diarrea',
#  'enfermedad',
#  'familia',
#  'conocido',
#  'colega',
#  'pareja',
#  'esposo',
#  'matrimonio',
#  'hermano',
#  'abuelo',
#  'bisabuelo',
#  'bisnieto',
#  'sobrino',
#  'criatura',
#  'especie',
#  'nacimiento',
#  'reproduccion',
#  'muerte',
#  'naturaleza',
#  'bosque',
#  'desierto',
#  'laguna',
#  'energia',
#  'animal',
#  'caballo',
#  'conejo',
#  'dragon',
#  'ciervo',
#  'jirafa',
#  'elefante',
#  'pajaro',
#  'gallina',
#  'gorrion',
#  'cuervo',
#  'aguila',
#  'halcon',
#  'camaron',
#  'langosta',
#  'sardina',
#  'calamar',
#  'insecto',
#  'mariposa',
#  'polilla',
#  'saltamontes',
#  'mosquito',
#  'cucaracha',
#  'caracol',
#  'babosa',
#  'lombriz',
#  'marisco',
#  'molusco',
#  'lagarto',
#  'serpiente',
#  'cocodrilo',
#  'alimento',
#  'comida',
#  'bebida',
#  'vegetal',
#  'planta',
#  'semilla',
#  'ciruela',
#  'almendra',
#  'castana',
#  'cebada',
#  'verdura',
#  'patatas',
#  'judias',
#  'rabano',
#  'zanahoria',
#  'manzana',
#  'naranja',
#  'platano',
#  'castano',
#  'durazno',
#  'tomate',
#  'sandia',
#  'gaseosa',
#  'tiempo',
#  'calendario',
#  'instante',
#  'momento',
#  'segundo',
#  'minuto',
#  'semana',
#  'decada',
#  'milenio',
#  'manana',
#  'amanecer',
#  'mediodia',
#  'anochecer',
#  'martes',
#  'miercoles',
#  'jueves',
#  'viernes',
#  'sabado',
#  'domingo',
#  'ambiente',
#  'espacio',
#  'entorno',
#  'superficie',
#  'volumen',
#  'region',
#  'planeta',
#  'estrella',
#  'galaxia',
#  'universo',
#  'despejado',
#  'nublado',
#  'lluvia',
#  'viento',
#  'trueno',
#  'tormenta',
#  'derecha',
#  'izquierda',
#  'diagonal',
#  'exterior',
#  'interior',
#  'tierra',
#  'hierro',
#  'milimetro',
#  'cantidad',
#  'medida',
#  'sociedad',
#  'comunidad',
#  'reunion',
#  'encuentro',
#  'estructura',
#  'administracion',
#  'organizacion',
#  'asociacion',
#  'empresa',
#  'equipo',
#  'autoridad',
#  'campana',
#  'comision',
#  'congreso',
#  'consejo',
#  'partido',
#  'nacion',
#  'gobierno',
#  'estado',
#  'provincia',
#  'departamento',
#  'municipio',
#  'democracia',
#  'dictadura',
#  'politica',
#  'politico',
#  'presidente',
#  'ministro',
#  'director',
#  'parlamentario',
#  'representante',
#  'gobernador',
#  'policia',
#  'bomberos',
#  'capital',
#  'ciudad',
#  'poblacion',
#  'pueblo',
#  'obligacion',
#  'libertad',
#  'derecho',
#  'permiso',
#  'prohibicion',
#  'constitucion',
#  'decreto',
#  'economia',
#  'consumo',
#  'demanda',
#  'compania',
#  'comercio',
#  'mercado',
#  'servicio',
#  'producto',
#  'produccion',
#  'transaccion',
#  'almacen',
#  'fabrica',
#  'cuenta',
#  'boleto',
#  'entrada',
#  'dinero',
#  'billete',
#  'vuelto',
#  'precio',
#  'escritorio',
#  'dormitorio',
#  'habitacion',
#  'cuarto',
#  'oficina',
#  'puerta',
#  'ventana',
#  'entrada',
#  'apartamento',
#  'edificio',
#  'construccion',
#  'elevador',
#  'escalera',
#  'aparato',
#  'camara',
#  'cuerda',
#  'bolsillo',
#  'paraguas',
#  'parasol',
#  'pantalla',
#  'trancar',
#  'escultura',
#  'revista',
#  'cuadro',
#  'grabado',
#  'electricidad',
#  'corriente',
#  'conexion',
#  'prenda',
#  'solapa',
#  'cremallera',
#  'cinturon',
#  'zapato',
#  'pantalon',
#  'camisa',
#  'camiseta',
#  'zapatilla',
#  'cordones',
#  'abrigo',
#  'chaqueta',
#  'calcetines',
#  'bragas',
#  'calzoncillo',
#  'sujetador',
#  'transporte',
#  'transito',
#  'vehiculo',
#  'subterraneo',
#  'camino',
#  'carretera',
#  'autopista',
#  'avenida',
#  'estacion',
#  'aeropuerto',
#  'automovil',
#  'ambulancia',
#  'numero',
#  'alfabeto',
#  'simbolo',
#  'comunicacion',
#  'expresion',
#  'periodismo',
#  'periodico',
#  'diccionario',
#  'documento',
#  'informe',
#  'noticia',
#  'computadora',
#  'japones',
#  'ingles',
#  'aleman',
#  'espanol',
#  'frances',
#  'blanco',
#  'naranja',
#  'amarillo',
#  'celeste',
#  'violeta',
#  'marron',
#  'cultura',
#  'actuacion',
#  'espectador',
#  'espectaculo',
#  'entretenimiento',
#  'dibujo',
#  'pintura',
#  'musica',
#  'religion',
#  'articulo',
#  'educacion',
#  'escuela',
#  'instituto',
#  'colegio',
#  'universidad',
#  'estudio',
#  'formacion',
#  'analisis',
#  'investigacion',
#  'conocimiento',
#  'informacion',
#  'manera',
#  'estilo',
#  'figura',
#  'elemento',
#  'ciencia',
#  'aritmetica',
#  'historia',
#  'geografia',
#  'deporte',
#  'carrera',
#  'competicion',
#  'busqueda',
#  'pregunta',
#  'respuesta',
#  'cuestion',
#  'solicitud',
#  'decision',
#  'eleccion',
#  'consejo',
#  'sugerencia',
#  'control',
#  'sistema',
#  'trabajo',
#  'empleo',
#  'profesion',
#  'esfuerzo',
#  'cuatro',
#  'millon',
#  'posicion',
#  'movimiento',
#  'velocidad',
#  'aceleracion',
#  'direccion',
#  'tamano',
#  'mayoria',
#  'minoria',
#  'aumento',
#  'reduccion',
#  'crecimiento',
#  'frente',
#  'aspecto',
#  'contenido',
#  'objeto',
#  'sector',
#  'palabra',
#  'nombre',
#  'codigo',
#  'secreto',
#  'formalidad',
#  'presente',
#  'pasado',
#  'futuro',
#  'ocasion',
#  'accion',
#  'actividad',
#  'programa',
#  'proyecto',
#  'acuerdo',
#  'actitud',
#  'atencion',
#  'capacidad',
#  'concepto',
#  'condicion',
#  'conjunto',
#  'creacion',
#  'destruccion',
#  'origen',
#  'destino',
#  'objetivo',
#  'funcion',
#  'relacion',
#  'realidad',
#  'situacion',
#  'problema',
#  'intento',
#  'solucion',
#  'efecto',
#  'resultado',
#  'fracaso',
#  'consecuencia',
#  'beneficio',
#  'perjuicio',
#  'calidad',
#  'ataque',
#  'defensa',
#  'conflicto',
#  'guerra',
#  'caracter',
#  'caracteristica',
#  'crisis',
#  'cambio',
#  'desarrollo',
#  'progreso',
#  'avance',
#  'retroceso',
#  'mejora',
#  'deterioro',
#  'comienzo',
#  'transcurso',
#  'secuencia',
#  'proceso',
#  'interrupcion',
#  'espera',
#  'diferencia',
#  'similitud',
#  'sentido',
#  'sensacion',
#  'olfato',
#  'conciencia',
#  'percepcion',
#  'imagen',
#  'fuerza',
#  'potencia',
#  'presencia',
#  'existencia',
#  'experiencia',
#  'posibilidad',
#  'probabilidad',
#  'verdad',
#  'mentira',
#  'acierto',
#  'equivocacion',
#  'necesidad',
#  'significado',
#  'caracter',
#  'personalidad',
#  'pensamiento',
#  'memoria',
#  'recuerdo',
#  'alegria',
#  'tristeza',
#  'placer',
#  'empatia',
#  'interes',
#  'aburrimiento',
#  'cansancio',
#  'sorpresa',
#  'seguridad',
#  'confianza',
#  'ejemplo',
#  'superior',
#  'inferior',
#  'central',
#  'lateral',
#  'frontal',
#  'trasero',
#  'cierto',
#  'importante',
#  'necesario',
#  'absoluto',
#  'relativo',
#  'barato',
#  'cualquier',
#  'actual',
#  'reciente',
#  'dificil',
#  'posible',
#  'imposible',
#  'probable',
#  'improbable',
#  'estricto',
#  'general',
#  'particular',
#  'especial',
#  'fuerte',
#  'correcto',
#  'incorrecto',
#  'contrario',
#  'diferente',
#  'parecido',
#  'diverso',
#  'manual',
#  'automatico',
#  'universal',
#  'mundial',
#  'continental',
#  'internacional',
#  'nacional',
#  'regional',
#  'urbano',
#  'social',
#  'politico',
#  'cultural',
#  'artistico',
#  'propio',
#  'publico',
#  'privado',
#  'grande',
#  'pequeno',
#  'amplio',
#  'angosto',
#  'compacto',
#  'delgado',
#  'grueso',
#  'caliente',
#  'ligero',
#  'pesado',
#  'flexible',
#  'blando',
#  'caluroso',
#  'fresco',
#  'delicioso',
#  'horrible',
#  'picante',
#  'salado',
#  'amargo',
#  'anterior',
#  'posterior',
#  'siguiente',
#  'cercano',
#  'lejano',
#  'separado',
#  'alejado',
#  'triste',
#  'solitario',
#  'contento',
#  'tranquilo',
#  'enojado',
#  'agitado',
#  'ansioso',
#  'interesado',
#  'aburrido',
#  'encantado',
#  'cansado',
#  'sorprendido',
#  'asustado',
#  'doloroso',
#  'picante',
#  'apestoso',
#  'primer',
#  'segundo',
#  'tercero',
#  'cuarto',
#  'quinto',
#  'decimo',
#  'centesimo',
#  'millonesimo',
#  'penultimo',
#  'ultimo',
#  'nuestro',
#  'vuestro',
#  'aparecer',
#  'desaparecer',
#  'existir',
#  'cambiar',
#  'crecer',
#  'volver',
#  'partir',
#  'llegar',
#  'llevar',
#  'arrojar',
#  'lanzar',
#  'agarrar',
#  'quitar',
#  'alcanzar',
#  'acercar',
#  'alejar',
#  'lanzar',
#  'arrojar',
#  'lanzar',
#  'agarrar',
#  'sujetar',
#  'golpear',
#  'patear',
#  'quitar',
#  'alcanzar',
#  'acercar',
#  'alejar',
#  'recoger',
#  'levantar',
#  'sentir',
#  'percibir',
#  'querer',
#  'desear',
#  'entristecerse',
#  'llorar',
#  'enojarse',
#  'admirar',
#  'alegrarse',
#  'encantarse',
#  'consolar',
#  'interesarse',
#  'aburrirse',
#  'cansarse',
#  'sorprenderse',
#  'asustarse',
#  'comunicarse',
#  'afirmar',
#  'hablar',
#  'callar',
#  'escribir',
#  'analizar',
#  'pensar',
#  'cantar',
#  'senalar',
#  'apunalar',
#  'morder',
#  'clavar',
#  'acordar',
#  'afectar',
#  'generar',
#  'anadir',
#  'mejorar',
#  'empeorar',
#  'seguir',
#  'avanzar',
#  'retroceder',
#  'ayudar',
#  'complicar',
#  'reunirse',
#  'entrevistar',
#  'faltar',
#  'recibir',
#  'romper',
#  'doblar',
#  'cortar',
#  'comprar',
#  'vender',
#  'cambiar',
#  'intercambiar',
#  'sustituir',
#  'cerrar',
#  'buscar',
#  'encontrar',
#  'obtener',
#  'comenzar',
#  'terminar',
#  'abandonar',
#  'entrar',
#  'quedarse',
#  'atender',
#  'considerar',
#  'comparar',
#  'evaluar',
#  'decidir',
#  'construir',
#  'destruir',
#  'conocer',
#  'entender',
#  'trabajar',
#  'separar',
#  'descansar',
#  'dormir',
#  'despertar',
#  'aceptar',
#  'rechazar',
#  'descartar',
#  'acompanar',
#  'pretender',
#  'proponer',
#  'sugerir',
#  'fabricar',
#  'arreglar',
#  'explicar',
#  'mostrar',
#  'tratar',
#  'evitar',
#  'probar',
#  'comprobar',
#  'variar',
#  'esperar',
#  'necesitar',
#  'significar',
#  'parecer',
#  'distinguir',
#  'apenas',
#  'aproximadamente',
#  'exactamente',
#  'bastante',
#  'demasiado',
#  'etcetera',
#  'cuando',
#  'cuanto',
#  'regular',
#  'despacio',
#  'deprisa',
#  'adrede',
#  'exacto',
#  'inclusive',
#  'ademas',
#  'asimismo',
#  'unicamente',
#  'especialmente',
#  'incluso',
#  'viceversa',
#  'siquiera',
#  'inicialmente',
#  'finalmente',
#  'siempre',
#  'tambien',
#  'tampoco',
#  'facilmente',
#  'dificilmente',
#  'probablemente',
#  'posiblemente',
#  'seguramente',
#  'anteriormente',
#  'actualmente',
#  'enseguida',
#  'inmediatamente',
#  'todavia',
#  'recien',
#  'mientras',
#  'despues',
#  'pronto',
#  'temprano',
#  'anoche',
#  'manana',
#  'proximamente',
#  'arriba',
#  'adelante',
#  'centro',
#  'alrededor',
#  'enfrente',
#  'adentro',
#  'afuera',
#  'adonde',
#  'contra',
#  'durante',
#  'mediante',
#  'aunque',
#  'cuando',
#  'entonces',
#  'excepto',
#  'porque',
#  'nosotros',
#  'vosotros',
#  'ustedes',
#  'nuestro',
#  'vuestro',
#  'ninguno',
#  'varios',
#  'alguien',
#  'cualquiera',
#  'cuanto',
#  'aquellos',
#  'gracias']

# %%
#luego hacemos las funciones necesarias para que no completen los huevos de letras 

def complete_letters(letters,word):
    word=list(word)
    cuales=[True if i in letters else False for i in word]
    final=[word[i] if cuales[i] else "_ " for i in range(len(cuales))]
    return "".join(final)

# %%
#el bot tiene que tener diferentes stages, y debe ir evolucionando conforme se juega
#y además saber cuando se termina 
KEY="5125128580:AAEfu8BO-mJvYYOI2hX8C8wo-EDF1AhqioA"
bot = telebot.TeleBot(KEY, parse_mode=None) # You can set parse_mode by default. HTML or MARKDOWN

#vamos a tener muchas callbacks pero solo se activaran cuando se le indique


 



#luego al adivinar se deben de pasar las letras una a una 
#pero si se pasa algo más largo de debe de detectar la palabra.

palabra=palabras[np.random.randint(0,len(palabras))]
jugando=False
letras=[]
hang_count=0
intentos_adiv=0
intentos_adiv_max=2


#primero debemos empezar
@bot.message_handler(commands=["start"])
def empezar(message):
    global jugando
    global palabra
    global palabras
    global letras
    global hang_count
    global intentos_adiv
    
    if jugando == False:
        jugando=True
        bot.send_message(message.chat.id, "Este es el juego del ahorcado.\n \
Para pedir letra simplemente escribela en el chat. \n Y para adivinar la palabra pon: 'Respuesta: {la palabra}'\
\n Y tienes 2 intentos.")
    elif jugando == True:
        bot.send_message(message.chat.id, "Reiniciamos el juego")
    letras=[]
    hang_count=0
    intentos_adiv=0
    intentos_adiv_max=2
    palabra=palabras[np.random.randint(0,len(palabras))]
    print(letras,palabra,complete_letters(letras,palabra))
    bot.send_message(message.chat.id, f"La palabra a adivinar es: \n {complete_letters(letras,palabra)}")
    bot.send_message(message.chat.id, f"{HANGMANPICS[0]}")





def enter_oneletter(message):
    x=message.text
    #funcion que activa la respueta si estamos jungando y se ha enviado una letra
    global jugando
    if jugando and len(x.strip())==1 and x.strip().isalpha():
        return True
    else:
        return False

@bot.message_handler(func=enter_oneletter)
def oneletter(message):
    x=message.text
    global palabra
    global letras
    global hang_count
    #entra si le he pasado una letra y estamos jugando

    #comprobamos si esta la letra en la palabra y sino sumamos una al moñeco
    if x.strip().lower() in letras:
        bot.send_message(message.chat.id, "Esa letra ya la ha dicho. Di otra venga.")

    elif x.strip().lower() in list(palabra):
        #si esta entonces palante y no sumamos
        letras.append(unidecode.unidecode((x.strip().lower())))
        
        bot.send_message(message.chat.id, f"La letra sí está, la palabra queda así: \n {complete_letters(letras,palabra)}")
        print(letras,palabra,complete_letters(letras,palabra))

    else:
        letras.append(unidecode.unidecode((x.strip().lower())))

        #si no esta sumamos una y printeamos
        hang_count+=1
        bot.send_message(message.chat.id, f"Esa letra NO está en la palabra: \n {complete_letters(letras,palabra)}")

        #comprobacion de que no hemos llegado al final de intentos
        bot.send_message(message.chat.id, f"{HANGMANPICS[hang_count]}")

        if hang_count>=6:
            #ha perdido
            jugando=False
            bot.send_message(message.chat.id,f"Has perdido, escribe '/start' para empezar una nueva partida.\
La palabra era '{palabra}'.")
            


#y si nos dice la palabra pues pasamo con eso a ver si la acierta
def enter_word(message):
    x=message.text
    global palabra
    global jugando
    #si metemos Respuesta: palabra
    #entonces comprobamos
    regex_aux=re.findall("^(.+):",x)
    if regex_aux:
        start_aux=regex_aux[0].lower().strip()
        intento_aux=re.findall(":(.+)$",x)[0]
        if intento_aux:
            palabra_intento=intento_aux.lower().strip()
        else:
            palabra_intento=None
        if jugando and len(x.strip())!=1 and start_aux=="respuesta" and palabra_intento is not None:
            return True
        else:
            return False
    else:
        return False
    
@bot.message_handler(func=enter_word)
def word(message):
    x=message.text
    global palabra
    global intentos_adiv
    #comprobamos si la palabra es
    palabra_intento=re.findall(":(.+)$",x)[0].lower().strip()
    if palabra_intento == palabra:
        #si es, terminamos y todo guay, se reinicia todo y damos la oportunidad de volver a empezar
        bot.send_message(message.chat.id, "Muy bien, la has adivinado, si quieres jugar otra vez pon '/start'")
        jugando=False

    else:
        #si no es, sumamos uno a lo de los intentos y le avisamo que no es.
        intentos_adiv+=1
        bot.send_message(message.chat.id, f"NO! ERROR, MAL!!, {palabra_intento} NO ES LA PALABRA.")

        #si no la a avinado y ya estamos en el máximo le avisamo y volvemos a comentar
        if intentos_adiv>=intentos_adiv_max:
            #terminamos
            jugando=False
            bot.send_message(message.chat.id, "Has agotado los intentos para adivinar la palabra, se reiniciará el juego.")

        

#tenemos que tener una funcion que compruebe que no se han pasado los intentos de letras y de palabras

# %%
bot.polling()
# Out:
# [] aburrido _ _ _ _ _ _ _ _
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/.local/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#
# ~/anaconda3/envs/env1/lib/python3.8/http/client.py in getresponse(self)
#    1347             try:
# -> 1348                 response.begin()
#    1349             except ConnectionError:
#
# ~/anaconda3/envs/env1/lib/python3.8/http/client.py in begin(self)
#     315         while True:
# --> 316             version, status, reason = self._read_status()
#     317             if status != CONTINUE:
#
# ~/anaconda3/envs/env1/lib/python3.8/http/client.py in _read_status(self)
#     276     def _read_status(self):
# --> 277         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278         if len(line) > _MAXLINE:
#
# ~/anaconda3/envs/env1/lib/python3.8/socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ~/anaconda3/envs/env1/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# ~/anaconda3/envs/env1/lib/python3.8/ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# ~/anaconda3/envs/env1/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439             if not chunked:
# --> 440                 resp = conn.urlopen(
#     441                     method=request.method,
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     784
# --> 785             retries = retries.increment(
#     786                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/.local/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     549             if read is False or not self._is_method_retryable(method):
# --> 550                 raise six.reraise(type(error), error, _stacktrace)
#     551             elif read is not None:
#
# ~/.local/lib/python3.8/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     769                 raise value.with_traceback(tb)
# --> 770             raise value
#     771         finally:
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     452             raise
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     339         if isinstance(err, SocketTimeout):
# --> 340             raise ReadTimeoutError(
#     341                 self, url, "Read timed out. (read timeout=%s)" % timeout_value
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.telegram.org', port=443): Read timed out. (read timeout=25)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# /tmp/ipykernel_16663/4032649321.py in <module>
# ----> 1 bot.polling()
#
# ~/anaconda3/envs/env1/lib/python3.8/site-packages/telebot/__init__.py in polling(self, non_stop, skip_pending, interval, timeout, long_polling_timeout, allowed_updates, none_stop)
#     656
#     657         if self.threaded:
# --> 658             self.__threaded_polling(non_stop, interval, timeout, long_polling_timeout, allowed_updates)
#     659         else:
#     660             self.__non_threaded_polling(non_stop, interval, timeout, long_polling_timeout, allowed_updates)
#
# ~/anaconda3/envs/env1/lib/python3.8/site-packages/telebot/__init__.py in __threaded_polling(self, non_stop, interval, timeout, long_polling_timeout, allowed_updates)
#     718                     polling_thread.clear_exceptions()   #*
#     719                     self.worker_pool.clear_exceptions() #*
# --> 720                     raise e
#     721                 else:
#     722                     polling_thread.clear_exceptions()
#
# ~/anaconda3/envs/env1/lib/python3.8/site-packages/telebot/__init__.py in __threaded_polling(self, non_stop, interval, timeout, long_polling_timeout, allowed_updates)
#     677                 polling_thread.put(self.__retrieve_updates, timeout, long_polling_timeout, allowed_updates=allowed_updates)
#     678                 or_event.wait()  # wait for polling thread finish, polling thread error or thread pool error
# --> 679                 polling_thread.raise_exceptions()
#     680                 self.worker_pool.raise_exceptions()
#     681                 error_interval = 0.25
#
# ~/anaconda3/envs/env1/lib/python3.8/site-packages/telebot/util.py in raise_exceptions(self)
#     103     def raise_exceptions(self):
#     104         if self.exception_event.is_set():
# --> 105             raise self.exception_info
#     106
#     107     def clear_exceptions(self):
#
# ~/anaconda3/envs/env1/lib/python3.8/site-packages/telebot/util.py in run(self)
#      85                 self.received_task_event.set()
#      86
# ---> 87                 task(*args, **kwargs)
#      88                 logger.debug("Task complete")
#      89                 self.done_event.set()
#
# ~/anaconda3/envs/env1/lib/python3.8/site-packages/telebot/__init__.py in __retrieve_updates(self, timeout, long_polling_timeout, allowed_updates)
#     405             logger.debug('Skipped all pending messages')
#     406             self.skip_pending = False
# --> 407         updates = self.get_updates(offset=(self.last_update_id + 1),
#     408                                    allowed_updates=allowed_updates,
#     409                                    timeout=timeout, long_polling_timeout=long_polling_timeout)
#
# ~/anaconda3/envs/env1/lib/python3.8/site-packages/telebot/__init__.py in get_updates(self, offset, limit, timeout, allowed_updates, long_polling_timeout)
#     385         :return: array of Updates
#     386         """
# --> 387         json_updates = apihelper.get_updates(self.token, offset, limit, timeout, allowed_updates, long_polling_timeout)
#     388         return [types.Update.de_json(ju) for ju in json_updates]
#     389
#
# ~/anaconda3/envs/env1/lib/python3.8/site-packages/telebot/apihelper.py in get_updates(token, offset, limit, timeout, allowed_updates, long_polling_timeout)
#     326     if allowed_updates is not None:  # Empty lists should pass
#     327         payload['allowed_updates'] = json.dumps(allowed_updates)
# --> 328     return _make_request(token, method_url, params=payload)
#     329
#     330
#
# ~/anaconda3/envs/env1/lib/python3.8/site-packages/telebot/apihelper.py in _make_request(token, method_name, method, params, files)
#     150             timeout=(connect_timeout, read_timeout), proxies=proxy)
#     151     else:
# --> 152         result = _get_req_session().request(
#     153             method, request_url, params=params, files=files,
#     154             timeout=(connect_timeout, read_timeout), proxies=proxy)
#
# ~/anaconda3/envs/env1/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# ~/anaconda3/envs/env1/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/env1/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     530                 raise SSLError(e, request=request)
#     531             elif isinstance(e, ReadTimeoutError):
# --> 532                 raise ReadTimeout(e, request=request)
#     533             elif isinstance(e, _InvalidHeader):
#     534                 raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='api.telegram.org', port=443): Read timed out. (read timeout=25)
